# %%
import pandas as pd

# %%
import matplotlib as plt

# %%
df1=pd.read_csv("Call.csv")
df2=pd.read_csv("Customer.csv")
df3=pd.read_csv("Order.csv")
df4=pd.read_csv("Product.csv")
df5=pd.read_csv("Supplier.csv")

# %%
df5
# Out:
#     supplier_id                   supplier_name supplier_since  \
# 0             1                     Denesik Inc    17-Dec-2018
# 1             2      Russel, Hickle and Ullrich    20-May-2017
# 2             3                Hickle-Langworth    25-Nov-2015
# 3             4         Rice, Hayes and Gleason    12-Jun-2019
# 4             5      Littel, Mann and Bahringer    26-Apr-2008
# ..          ...                             ...            ...
# 95           96                 Satterfield Inc    15-Sep-2017
# 96           97  Kertzmann, Labadie and Mueller    13-Jan-2011
# 97           98                     Schaden Inc    16-Dec-2014
# 98           99                       Olson LLC    30-Jan-2016
# 99          100      Gerlach, Emard and Bartell    10-May-2013
#
#              street_address           city state_province        country  \
# 0           9824 Haas Place       San Jose     California  United States
# ...

# %%
df2['city'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

ax=sns.histplot(binwidth=0.5, x="city", hue="prime_member", data=df2, stat="count", multiple="stack")
ax.set_xticklabels(df2['city'].tolist(), 
                          rotation=90, 
                          horizontalalignment='right')
# Out:
# /var/folders/ys/qhjkm3dd3r9bs4f8ndl340dw0000gn/T/ipykernel_7996/2118142177.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df2['city'].tolist(),
# [Text(0, 0, 'Fort Worth'),
#  Text(1, 0, 'Denton'),
#  Text(2, 0, 'Fort Worth'),
#  Text(3, 0, 'Amarillo'),
#  Text(4, 0, 'Austin'),
#  Text(5, 0, 'El Paso'),
#  Text(6, 0, 'El Paso'),
#  Text(7, 0, 'Houston'),
#  Text(8, 0, 'Fort Worth'),
#  Text(9, 0, 'Waco'),
#  Text(10, 0, 'Dallas'),
#  Text(11, 0, 'El Paso'),
#  Text(12, 0, 'Waco'),
#  Text(13, 0, 'Mesquite'),
#  Text(14, 0, 'Fort Worth'),
#  Text(15, 0, 'Dallas'),
#  Text(16, 0, 'Dallas'),
#  Text(17, 0, 'Dallas'),
#  Text(18, 0, 'Austin'),
#  Text(19, 0, 'Austin'),
#  Text(20, 0, 'El Paso'),
#  Text(21, 0, 'Waco'),
#  Text(22, 0, 'Tyler'),
#  Text(23, 0, 'Dallas'),
#  Text(24, 0, 'El Paso'),
#  Text(25, 0, 'Amarillo'),
#  Text(26, 0, 'Spring')]

# %%
df1.plot(x='call_length', y='satisfaction', style='o')
# Out:
# <AxesSubplot:xlabel='call_length'>

# %%
df5=df4[df4["product_category"]=="Clothing"]
value_dict=dict()
value_dict["Clothing"]=df5["average_rating"].mean()
df5=df4[df4["product_category"]=="Kitchen"]

value_dict["Kitchen"]=df5["average_rating"].mean()
df5=df4[df4["product_category"]=="Electronics"]

value_dict["Electronics"]=df5["average_rating"].mean()

# %%
plt.bar(value_dict.keys(), value_dict.values(),  color='g')
# Out:
# <BarContainer object of 3 artists>

# %%
df3['payment_type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df5['state_province'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
